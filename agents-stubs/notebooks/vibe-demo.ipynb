# %% [markdown]
# # Vibe Demo
#
# Run the local vibe pipeline and inspect outputs.

# %%
from agents_stubs.vibe import run_sample
review, manifest = run_sample()
print(manifest)
